# %%
import urllib.parse
import webbrowser

# %%
job_title = "Remote Python Developer"
print(f" AI Agent: Formatting your search for '{job_title}'...")
# Out:
#  AI Agent: Formatting your search for 'Remote Python Developer'...

# %%
clean_job_title = urllib.parse.quote(job_title)

# %%
google_url = f"https://www.google.com/search?q={clean_job_title}+jobs&tbs=qdr:d"

# %%
print("AI Agent: Opening Google with 24-hour job filters applied!")
# Out:
# AI Agent: Opening Google with 24-hour job filters applied!

# %%
webbrowser.open(google_url)
# Out:
# False

# %%
print(google_url)
# Out:
# https://www.google.com/search?q=Remote%20Python%20Developer+jobs&tbs=qdr:d
